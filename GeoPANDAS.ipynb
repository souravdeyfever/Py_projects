# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
ind = gpd.read_file('D:\satellite_data\Sem_III\India_shp_let\India_state_boundary\India_State_Boundary.shp')

# %%
ind.head()

# %%
ind.plot()
# Out:
# <AxesSubplot: >

# %%
ind.plot(cmap='jet')
# Out:
# <AxesSubplot: >

# %%
view(ind)
